# %% [markdown]
# # Introduction
#
# ### Problem
#
# In the project this week, we will conduct detailed model evaluation, data quality testing and behavioral testing for the news classification model from the week 1 project.
#
# 1. We will look at evaluation metrics beyond overall accuracy and f1 score (per-class metrics, confusion matrix, per-class false positive and false negative errors)
# 2. We will implement bootstrap sampling to measure confidence intervals of model performance metrics
# 3. We will implement behavioral tests using a popular open source library called checklist
# 4. [advanced] Advanced data quality and behavioral tests
#
# ### Deliverables
# 1. Test set per-class accuracy, precision, recall and F-1 score
# 2. Test set confusion matrix, and per-class false positive, false negative errors
# 3. 95% confidence intervals for test set metrics as estimated via bootstrap sampling
# 4. Behavioral tests for the trained news classification model, using checklist.
# 5. [Optional] Advanced data quality and behavioral tests

# %% [markdown]
# ## Step1: Prereqs & Installation
#
# Download & Import all the necessary libraries we need throughout the project.

# %%
# Install all the required dependencies for the project

# !pip install numpy
# !pip install scikit-learn
# !pip install gensim
# !pip install sentence-transformers
# !pip install matplotlib
# !pip install great_expectations
# Out:
# Requirement already satisfied: numpy in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (1.24.2)
# Requirement already satisfied: scikit-learn in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from scikit-learn) (1.24.2)
# Requirement already satisfied: scipy>=1.3.2 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: gensim in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (4.3.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from gensim) (1.24.2)
# Requirement already satisfied: scipy>=1.7.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from gensim) (6.3.0)
# Requirement already satisfied: sentence-transformers in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from sentence-transformers) (4.29.2)
# Requirement already satisfied: tqdm in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from sentence-transformers) (2.0.1)
# Requirement already satisfied: torchvision in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from sentence-transformers) (0.15.2)
# Requirement already satisfied: numpy in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from sentence-transformers) (1.24.2)
# Requirement already satisfied: scikit-learn in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: nltk in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from sentence-transformers) (0.15.1)
# Requirement already satisfied: filelock in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.12.0)
# Requirement already satisfied: fsspec in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.5.0)
# Requirement already satisfied: requests in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.30.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.6.3)
# Requirement already satisfied: packaging>=20.9 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.1)
# Requirement already satisfied: sympy in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.6.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.13.3)
# Requirement already satisfied: click in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nltk->sentence-transformers) (8.1.3)
# Requirement already satisfied: joblib in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from torchvision->sentence-transformers) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: matplotlib in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: great_expectations in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (0.17.0)
# Requirement already satisfied: altair<5.0.0,>=4.2.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (4.2.2)
# Requirement already satisfied: Click>=7.1.2 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (8.1.3)
# Requirement already satisfied: colorama>=0.4.3 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (0.4.6)
# Requirement already satisfied: cryptography>=3.2 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (41.0.1)
# Requirement already satisfied: importlib-metadata>=1.7.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (6.6.0)
# Requirement already satisfied: Ipython>=7.16.3 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (8.13.2)
# Requirement already satisfied: ipywidgets>=7.5.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (8.0.6)
# Requirement already satisfied: jinja2>=2.10 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (3.1.2)
# Requirement already satisfied: jsonpatch>=1.22 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (1.33)
# Requirement already satisfied: jsonschema>=2.5.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (4.17.3)
# Requirement already satisfied: makefun<2,>=1.7.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (1.15.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.7.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (3.19.0)
# Requirement already satisfied: mistune>=0.8.4 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (2.0.5)
# Requirement already satisfied: nbformat>=5.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (5.9.0)
# Requirement already satisfied: notebook>=6.4.10 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (6.5.4)
# Requirement already satisfied: packaging in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (23.1)
# Requirement already satisfied: pydantic<2.0,>=1.9.2 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (1.10.8)
# Requirement already satisfied: pyparsing>=2.4 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (2.8.2)
# Requirement already satisfied: pytz>=2021.3 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (2023.3)
# Requirement already satisfied: requests>=2.20 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (2.30.0)
# Requirement already satisfied: ruamel.yaml<0.17.18,>=0.16 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (0.17.17)
# Requirement already satisfied: scipy>=1.6.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (1.10.1)
# Requirement already satisfied: tqdm>=4.59.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (4.6.3)
# Requirement already satisfied: tzlocal>=1.2 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (5.0.1)
# Requirement already satisfied: urllib3>=1.26 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (1.26.15)
# Requirement already satisfied: numpy>=1.23.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (1.24.2)
# Requirement already satisfied: pandas>=1.3.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from great_expectations) (2.0.0)
# Requirement already satisfied: entrypoints in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from altair<5.0.0,>=4.2.1->great_expectations) (0.4)
# Requirement already satisfied: toolz in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from altair<5.0.0,>=4.2.1->great_expectations) (0.12.0)
# Requirement already satisfied: cffi>=1.12 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from cryptography>=3.2->great_expectations) (1.15.1)
# Requirement already satisfied: zipp>=0.5 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from importlib-metadata>=1.7.0->great_expectations) (3.15.0)
# Requirement already satisfied: backcall in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (0.2.0)
# Requirement already satisfied: decorator in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (2.15.1)
# Requirement already satisfied: stack-data in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (5.9.0)
# Requirement already satisfied: pexpect>4.3 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (4.8.0)
# Requirement already satisfied: appnope in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from Ipython>=7.16.3->great_expectations) (0.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipywidgets>=7.5.1->great_expectations) (6.23.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipywidgets>=7.5.1->great_expectations) (4.0.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipywidgets>=7.5.1->great_expectations) (3.0.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jinja2>=2.10->great_expectations) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jsonpatch>=1.22->great_expectations) (2.4)
# Requirement already satisfied: attrs>=17.4.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (0.19.3)
# Requirement already satisfied: fastjsonschema in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbformat>=5.0->great_expectations) (2.17.1)
# Requirement already satisfied: jupyter-core in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbformat>=5.0->great_expectations) (5.3.0)
# Requirement already satisfied: tornado>=6.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (6.3.1)
# Requirement already satisfied: pyzmq>=17 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (25.0.2)
# Requirement already satisfied: argon2-cffi in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (21.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (8.2.0)
# Requirement already satisfied: ipython-genutils in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (0.2.0)
# Requirement already satisfied: nbconvert>=5 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (7.5.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (0.17.1)
# Requirement already satisfied: prometheus-client in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (0.17.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from notebook>=6.4.10->great_expectations) (1.0.0)
# Requirement already satisfied: tzdata>=2022.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from pandas>=1.3.0->great_expectations) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from python-dateutil>=2.8.1->great_expectations) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests>=2.20->great_expectations) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests>=2.20->great_expectations) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests>=2.20->great_expectations) (2023.5.7)
# Requirement already satisfied: pycparser in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.2->great_expectations) (2.21)
# Requirement already satisfied: comm>=0.1.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations) (1.6.7)
# Requirement already satisfied: psutil in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations) (5.9.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jedi>=0.16->Ipython>=7.16.3->great_expectations) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-core->nbformat>=5.0->great_expectations) (3.5.0)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (2.6.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (0.2.3)
# Requirement already satisfied: beautifulsoup4 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (6.0.0)
# Requirement already satisfied: defusedxml in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (1.5.0)
# Requirement already satisfied: tinycss2 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (1.2.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from pexpect>4.3->Ipython>=7.16.3->great_expectations) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->Ipython>=7.16.3->great_expectations) (0.2.6)
# Requirement already satisfied: argon2-cffi-bindings in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from argon2-cffi->notebook>=6.4.10->great_expectations) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from stack-data->Ipython>=7.16.3->great_expectations) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from stack-data->Ipython>=7.16.3->great_expectations) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from stack-data->Ipython>=7.16.3->great_expectations) (0.2.2)
# Requirement already satisfied: webencodings in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert>=5->notebook>=6.4.10->great_expectations) (0.5.1)
# Requirement already satisfied: anyio>=3.1.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (3.7.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (0.4.4)
# Requirement already satisfied: overrides in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (7.3.1)
# Requirement already satisfied: websocket-client in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (1.5.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=6.4.10->great_expectations) (2.4.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (1.3.0)
# Requirement already satisfied: exceptiongroup in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (1.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (6.0)
# Requirement already satisfied: rfc3339-validator in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (0.1.1)
# Requirement already satisfied: fqdn in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (1.5.1)
# Requirement already satisfied: isoduration in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (20.11.0)
# Requirement already satisfied: uri-template in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (1.2.0)
# Requirement already satisfied: webcolors>=1.11 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jsonschema>=2.5.1->great_expectations) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from isoduration->jsonschema>=2.5.1->great_expectations) (1.2.3)

# %%
# Package imports that will be needed for this project

import numpy as np
import json
from sentence_transformers import SentenceTransformer
from pprint import pprint
from sklearn.linear_model import LogisticRegression
from sklearn import metrics as sklearn_metrics

# %%
# Global Constants

LABEL_SET = [
    'Business',
    'Sci/Tech',
    'Software and Developement',
    'Entertainment',
    'Sports',
    'Health',
    'Toons',
    'Music Feeds'
]

EMBEDDING_MODEL = 'all-mpnet-base-v2'
DATA_URL = 'https://corise-mlops.s3.us-west-2.amazonaws.com/project2/agnews.zip'

# %% [markdown]
# ## Step 2: Download and Load Dataset
#
# [AG News](http://groups.di.unipi.it/~gulli/AG_corpus_of_news_articles.html) is a collection of more than 1 million news articles gathered from more than 2000 news sources by an academic news search engine. The news topic classification dataset & benchmark was first used in [Character-level Convolutional Networks for Text Classification (NIPS 2015)](https://arxiv.org/abs/1509.01626). The dataset has the text description (summary) of the news article along with some metadata. **For this project, we will use a slightly modified (cleaned up) version of this dataset**
#
# Schema:
# * Source - News publication source
# * URL - URL of the news article
# * Title - Title of the news article
# * Description - Summary description of the news article
# * Embedding - 768 dimensional embedding representation of the news article text (description)
# * Category (Label) - News category
#
# Sample row in this dataset:
# ```
# {
#    'description': 'A capsule carrying solar material from the Genesis space probe has made a crash landing at a US Air Force training facility in the US state of Utah.',
#    'id': 86273,
#    'label': 'Entertainment',
#    'source': 'Voice of America',
#    'title': 'Capsule from Genesis Space Probe Crashes in Utah Desert',
#    'Embedding': [....],
#    'url': 'http://www.sciencedaily.com/releases/2004/09/040908090621.htm'
# }
# ```

# %%
from urllib.request import urlopen
from io import BytesIO
from zipfile import ZipFile

DIRECTORY_NAME = "data"


def download_dataset():
    """
    Download the dataset. The zip contains three files: train.json, test.json and unlabeled.json
    """
    http_response = urlopen(DATA_URL)
    zipfile = ZipFile(BytesIO(http_response.read()))
    zipfile.extractall(path=DIRECTORY_NAME)


# Expensive operation so we should just do this once
download_dataset()

# %%
Datasets = {}

for ds in ['train', 'test']:
    with open('data/{}.json'.format(ds), 'r') as f:
        Datasets[ds] = json.load(f)
    print("Loaded Dataset {0} with {1} rows".format(ds, len(Datasets[ds])))

print("\nExample dataset row:\n")
pprint(Datasets['train'][0])
# Out:
# Loaded Dataset train with 25000 rows
# Loaded Dataset test with 50000 rows
#
# Example dataset row:
#
# {'description': 'A capsule carrying solar material from the Genesis space '
#                 'probe has made a crash landing at a US Air Force training '
#                 'facility in the US state of Utah.',
#  'embedding': [0.014944990165531635,
#                -0.012602416798472404,
#                0.022629551589488983,
#                -0.004524254705756903,
#                0.030837086960673332,
#                -0.036378033459186554,
#                -0.009855341166257858,
#                0.03661152347922325,
#                0.006519013550132513,
#                0.01946776919066906,
#                0.059149134904146194,
#                0.10400382429361343,
#                0.02093622088432312,
#                0.015259518288075924,
#                -0.0015271983575075865,
#                -0.0564558282494545,
#                0.015183313749730587,
#                0.023458128795027733,
#                -0.017082693055272102,
#                1.861398059591977e-34,
#                0.010035979561507702,
#                -0.05358980968594551,
#                -0.013858268968760967,
#                0.0012140555772930384,
#                -0.004098637029528618,
#                0.008830065838992596,
#                0.06796347349882126,
#                -0.004755877889692783,
#                -0.017070347443223,
#                -0.004947595298290253,
#                -0.0005722247296944261],
#  'id': 86273,
#  'label': 'Entertainment',
#  'rank': '5',
#  'source': 'Voice of America',
#  'title': 'Capsule from Genesis Space Probe Crashes in Utah Desert',
#  'url': 'http://www.sciencedaily.com/releases/2004/09/040908090621.htm'}

# %% [markdown]
# ## Step 3: Data Quality Tests
#
# In Week 2 instruction, we learned about the importance of evaluating data quality across the ML lifecycle:
# * When building your first ML model, you often have no data and have to invest in annotation resources to get labels
# * Dataset labels can be noisy as they are collected from a variety of different sources.
# * Real world evolves (drift) and so should the datasets you’re using to train models (to make sure they evolve along with it).
#
# [Great Expectations](https://docs.greatexpectations.io/docs/) is a popular Python library for validating data in Machine Learning pipelines. It contains several built-in Expectation types to configure tests, as well as integrations with common data structures used to store datasets (e.g. Pandas dataframes, CSV files, MySQL databases etc). We will be using this library to define and run some data quality tests for our dataset. The goal and scope of the exercise here is to get you acquainted with the library and practice of testing for data quality.
#
# Useful references for this section:
# 1. Documentation: https://docs.greatexpectations.io/docs/
# 2. Using Great Expections in Jupyter: https://docs.greatexpectations.io/docs/guides/miscellaneous/how_to_quickly_explore_expectations_in_a_notebook
# 3. List of predefined Expecations: https://greatexpectations.io/expectations/
# 4. Creating custom Expecations for Pandas dataframes: https://github.com/great-expectations/great_expectations/blob/develop/docs_rtd/guides/how_to_guides/creating_and_editing_expectations/how_to_create_custom_expectations_for_pandas.rst

# %% [markdown]
# ### More notes
# * Why not use directly isnull or eq("") -->
#     *   The map function is a more efficient way to check for NULL and empty values than using the isnull method. This is because the isnull method has to iterate over the entire column to find any NULL values. The map function, on the other hand, can check for NULL values in parallel. This can significantly improve the performance of the function, especially for large columns.

# %%
import pandas as pd
import great_expectations as ge
from great_expectations.dataset import PandasDataset, MetaPandasDataset

class AGNewsPandasDataset(PandasDataset):

    _data_asset_type = "AGNewsPandasDataset"

    @MetaPandasDataset.column_map_expectation
    def expect_column_string_not_null_or_empty(self, column):
        """
        [TO BE IMPLEMENTED]

        Write a custom expectation that checks that the string column's value for each
        row is not NULL and not an empty string

        Your code should look something like this:
        column.map(lambda x: ...)
        """
        return column.map(lambda x: (x is not None) and (x != ""))

    @MetaPandasDataset.column_map_expectation
    def expect_column_embedding_dimensionality(self, column, dimension):
        """
        [TO BE IMPLEMENTED]

        Write a custom expectation that checks that the embedding column's value for each
        row is not NULL and dim(embedding) == dimension

        Your code should look something like this:
        column.map(lambda x: ...)
        """
        return column.map(lambda x: (x is not None) and (len(x) == dimension))

    @MetaPandasDataset.column_map_expectation
    def expect_column_in_range(self, column, range_min, range_max):
        """
        [TO BE IMPLEMENTED]

        Write a custom expectation that checks that the column's value for each
        row is in range [range_min, range_max]

        Your code should look something like this:
        column.map(lambda x: ...)
        """
        return column.map(lambda x: range_min <= int(x) <= range_max)
        
        # if not column.map(lambda x: x >= range_min and x <= range_max).all():
        #     raise ValueError("Values must be in range [{}, {}]".format(range_min, range_max))
        # return column.map(lambda x: range_min <= int(x) <= range_max)

    @MetaPandasDataset.column_map_expectation
    def expect_column_embedding_unit_norm(self, column):
        """
        [TO BE IMPLEMENTED]

        Write a custom expectation that checks that the embedding column's value for each
        row is not NULL and norm(embedding) == 1

        Your code should look something like this:
        column.map(lambda x: ...)
        """
        return column.map(lambda x: (x is not None) and (round(np.linalg.norm(np.array(x)), 2) == 1))

# %%
Dataframes = {}

for ds in ['train', 'test']:
    Dataframes[ds] = ge.from_pandas(
        pd.DataFrame.from_records(Datasets[ds]),
        dataset_class=AGNewsPandasDataset
    )

# %%
Dataframes['train']
# Out:
#            id             source
# 0       86273   Voice of America  \
# 1      488548   The Mac Observer
# 2      227379         Yahoo Tech
# 3      146915  Chicago Sun Times
# 4      205960            WSTM-TV
# ...       ...                ...
# 24995   79466                CNN
# 24996  105592       The Register
# 24997  100425    Washington Post
# 24998  149996           Guardian
# 24999  392762  Salt Lake Tribune
#
#                                                    title
# 0      Capsule from Genesis Space Probe Crashes in Ut...  \
# 1      Tunes Music Store Downloads Top 200 Million So...
# 2           China Offers Rewards for Reporting Porn (AP)
# 3                   Time for Euros to have fun in majors
# 4      Lawyer: US wrecking life of man searched in an...
# ...                                                  ...
# 24995                  Turkish government: Hostage freed
# 24996          Virus writers add network sniffer to worm
# 24997          In New York, Olympics Can Be Spelled JETS
# 24998                  Study finds dogs can smell cancer
# 24999                        Clinton library opens doors
#
#                                                      url rank
# 0      http://www.sciencedaily.com/releases/2004/09/0...    5  \
# 1      http://www.macnewsworld.com/story/Apple-Disabl...    5
# 2      http://us.rd.yahoo.com/dailynews/rss/tech/*htt...    5
# 3      http://www.indystar.com/articles/3/180376-2383...    5
# 4      http://seattlepi.nwsource.com/national/apus_st...    5
# ...                                                  ...  ...
# 24995  http://www.ctv.ca/servlet/ArticleNews/story/CT...    5
# 24996  http://www.theregister.co.uk/2004/09/14/networ...    5
# 24997  http://www.eurosport.com/home/pages/V4/L0/S6/E...    5
# 24998  http://www.newscientist.com/news/news.jsp?id=n...    5
# 24999  http://news.xinhuanet.com/english/2004-11/19/c...    5
#
#                                              description
# 0      A capsule carrying solar material from the Gen...  \
# 1      Apple Computer Apple announced Thursday that m...
# 2      AP - China's police ministry on Sunday handed ...
# 3      So enough about why the United States can #39;...
# 4      TOMS RIVER, NJ A lawyer for Doctor Kenneth Ber...
# ...                                                  ...
# 24995  Turkish Foreign Minister Abdullah Gul reported...
# 24996  Virus writers have grafted a network sniffer i...
# 24997  New York will be forced to abandon its bid to ...
# 24998  Dogs can sniff out cancer, a study shows today...
# 24999  Before a sea of umbrellas, three past presiden...
#
#                                                embedding          label
# 0      [0.014944990165531635, -0.012602416798472404, ...  Entertainment
# 1      [0.016263173893094063, 0.05981703847646713, -0...       Sci/Tech
# 2      [0.051430340856313705, 0.014167562127113342, -...       Sci/Tech
# 3      [-0.021981434896588326, 0.025182634592056274, ...         Sports
# 4      [0.020410768687725067, 0.1163247674703598, 0.0...         Health
# ...                                                  ...            ...
# 24995  [0.014458844438195229, 0.01171039417386055, 0....  Entertainment
# 24996  [0.014189074747264385, -0.008578748442232609, ...       Sci/Tech
# 24997  [-0.04604348540306091, 0.08192720264196396, 0....         Sports
# 24998  [0.05253065750002861, 0.046797558665275574, -0...  Entertainment
# 24999  [0.02175227552652359, 0.025092100724577904, 0....  Entertainment
#
# [25000 rows x 8 columns]

# %%
for ds in ['train', 'test']:
    """
    [TO BE IMPLEMENTED]

    Expect columns in Dataframes[ds] to match the column set:
    {'id', 'source', 'title', 'url', 'rank', 'description', 'embedding', 'label'}
    """
    # Check if the columns in Dataframes[ds] match the column set
    Dataframes[ds].expect_table_columns_to_match_set(set(
        {'id', 'source', 'title', 'url', 'rank', 'description', 'embedding', 'label'}))


    """
    [TO BE IMPLEMENTED]

    Expect the "id" column in Dataframes[ds] to be unique
    """
    # Check if the "id" column in Dataframes[ds] is unique
    Dataframes[ds].expect_column_values_to_be_unique("id")

    """
    [TO BE IMPLEMENTED]

    Expect the "description" column in Dataframes[ds] not not be null or empty
    """
    # Check if the "description" column in Dataframes[ds] is not null or empty
    Dataframes[ds].expect_column_string_not_null_or_empty("description")
    """
    [TO BE IMPLEMENTED]

    Expect the "embedding" column in Dataframes[ds] should be non-NULL and dimensionality = 768
    (Run this after implementing `expect_column_embedding_dimensionality` above)
    """
    # Check if the "embedding" column in Dataframes[ds] is non-NULL and dimensionality = 768
    Dataframes[ds].expect_column_embedding_dimensionality("embedding", 768)

    """
    [TO BE IMPLEMENTED]

    Expect the "embedding" column in Dataframes[ds] should be unit norm vectors
    (Run this after implementing `expect_column_embedding_unit_norm` above)
    """
    # Check if the "embedding" column in Dataframes[ds] are unit norm vectors
    Dataframes[ds].expect_column_embedding_unit_norm("embedding")

    """
    [TO BE IMPLEMENTED]

    Expect the "rank" column in Dataframes[ds] should be in range [1, 5]
    """
    # Check if the "rank" column in Dataframes[ds] is in range [1, 5]
    Dataframes[ds].expect_column_in_range("rank", 1, 5)

# %%
validation_train = Dataframes["train"].validate()

pprint(validation_train)
# Out:
# {
#   "statistics": {
#     "evaluated_expectations": 6,
#     "successful_expectations": 5,
#     "unsuccessful_expectations": 1,
#     "success_percent": 83.33333333333334
#   },
#   "results": [
#     {
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "success": true,
#       "expectation_config": {
#         "kwargs": {
#           "column_set": [
#             "title",
#             "source",
#             "id",
#             "url",
#             "rank",
#             "description",
#             "label",
#             "embedding"
#           ],
#           "result_format": "BASIC"
#         },
#         "expectation_type": "expect_table_columns_to_match_set",
#         "meta": {}
#       },
#       "result": {
#         "observed_value": [
#           "id",
#           "source",
#           "title",
#           "url",
#           "rank",
#           "description",
#           "embedding",
#           "label"
#         ]
#       },
#       "meta": {}
#     },
#     {
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "success": true,
#       "expectation_config": {
#         "kwargs": {
#           "column": "id",
#           "result_format": "BASIC"
#         },
#         "expectation_type": "expect_column_values_to_be_unique",
#         "meta": {}
#       },
#       "result": {
#         "element_count": 25000,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {}
#     },
#     {
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "success": false,
#       "expectation_config": {
#         "kwargs": {
#           "column": "description",
#           "result_format": "BASIC"
#         },
#         "expectation_type": "expect_column_string_not_null_or_empty",
#         "meta": {}
#       },
#       "result": {
#         "element_count": 25000,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 264,
#         "unexpected_percent": 1.056,
#         "unexpected_percent_total": 1.056,
#         "unexpected_percent_nonmissing": 1.056,
#         "partial_unexpected_list": [
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           ""
#         ]
#       },
#       "meta": {}
#     },
#     {
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "success": true,
#       "expectation_config": {
#         "kwargs": {
#           "column": "embedding",
#           "dimension": 768,
#           "result_format": "BASIC"
#         },
#         "expectation_type": "expect_column_embedding_dimensionality",
#         "meta": {}
#       },
#       "result": {
#         "element_count": 25000,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {}
#     },
#     {
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "success": true,
#       "expectation_config": {
#         "kwargs": {
#           "column": "embedding",
#           "result_format": "BASIC"
#         },
#         "expectation_type": "expect_column_embedding_unit_norm",
#         "meta": {}
#       },
#       "result": {
#         "element_count": 25000,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {}
#     },
#     {
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "success": true,
#       "expectation_config": {
#         "kwargs": {
#           "column": "rank",
#           "range_min": 1,
#           "range_max": 5,
#           "result_format": "BASIC"
#         },
#         "expectation_type": "expect_column_in_range",
#         "meta": {}
#       },
#       "result": {
#         "element_count": 25000,
#         "missing_count": 274,
#         "missing_percent": 1.0959999999999999,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {}
#     }
#   ],
#   "evaluation_parameters": {},
#   "success": false,
#   "meta": {
#     "great_expectations_version": "0.17.0",
#     "expectation_suite_name": "default",
#     "run_id": {
#       "run_name": null,
#       "run_time": "2023-06-21T17:35:02.859579-05:00"
#     },
#     "batch_kwargs": {
#       "ge_batch_id": "daa1ca1c-1083-11ee-a624-2662aa805206"
#     },
#     "batch_markers": {},
#     "batch_parameters": {},
#     "validation_time": "20230621T223502.859540Z",
#     "expectation_suite_meta": {
#       "great_expectations_version": "0.17.0"
#     }
#   }
# }

# %%
validation_test = Dataframes["test"].validate()

pprint(validation_test)
# Out:
# {
#   "statistics": {
#     "evaluated_expectations": 6,
#     "successful_expectations": 5,
#     "unsuccessful_expectations": 1,
#     "success_percent": 83.33333333333334
#   },
#   "results": [
#     {
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "success": true,
#       "expectation_config": {
#         "kwargs": {
#           "column_set": [
#             "title",
#             "source",
#             "id",
#             "url",
#             "rank",
#             "description",
#             "label",
#             "embedding"
#           ],
#           "result_format": "BASIC"
#         },
#         "expectation_type": "expect_table_columns_to_match_set",
#         "meta": {}
#       },
#       "result": {
#         "observed_value": [
#           "id",
#           "source",
#           "title",
#           "url",
#           "rank",
#           "description",
#           "embedding",
#           "label"
#         ]
#       },
#       "meta": {}
#     },
#     {
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "success": true,
#       "expectation_config": {
#         "kwargs": {
#           "column": "id",
#           "result_format": "BASIC"
#         },
#         "expectation_type": "expect_column_values_to_be_unique",
#         "meta": {}
#       },
#       "result": {
#         "element_count": 50000,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {}
#     },
#     {
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "success": false,
#       "expectation_config": {
#         "kwargs": {
#           "column": "description",
#           "result_format": "BASIC"
#         },
#         "expectation_type": "expect_column_string_not_null_or_empty",
#         "meta": {}
#       },
#       "result": {
#         "element_count": 50000,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 514,
#         "unexpected_percent": 1.028,
#         "unexpected_percent_total": 1.028,
#         "unexpected_percent_nonmissing": 1.028,
#         "partial_unexpected_list": [
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           "",
#           ""
#         ]
#       },
#       "meta": {}
#     },
#     {
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "success": true,
#       "expectation_config": {
#         "kwargs": {
#           "column": "embedding",
#           "dimension": 768,
#           "result_format": "BASIC"
#         },
#         "expectation_type": "expect_column_embedding_dimensionality",
#         "meta": {}
#       },
#       "result": {
#         "element_count": 50000,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {}
#     },
#     {
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "success": true,
#       "expectation_config": {
#         "kwargs": {
#           "column": "embedding",
#           "result_format": "BASIC"
#         },
#         "expectation_type": "expect_column_embedding_unit_norm",
#         "meta": {}
#       },
#       "result": {
#         "element_count": 50000,
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {}
#     },
#     {
#       "exception_info": {
#         "raised_exception": false,
#         "exception_message": null,
#         "exception_traceback": null
#       },
#       "success": true,
#       "expectation_config": {
#         "kwargs": {
#           "column": "rank",
#           "range_min": 1,
#           "range_max": 5,
#           "result_format": "BASIC"
#         },
#         "expectation_type": "expect_column_in_range",
#         "meta": {}
#       },
#       "result": {
#         "element_count": 50000,
#         "missing_count": 540,
#         "missing_percent": 1.08,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_list": []
#       },
#       "meta": {}
#     }
#   ],
#   "evaluation_parameters": {},
#   "success": false,
#   "meta": {
#     "great_expectations_version": "0.17.0",
#     "expectation_suite_name": "default",
#     "run_id": {
#       "run_name": null,
#       "run_time": "2023-06-21T17:35:03.418519-05:00"
#     },
#     "batch_kwargs": {
#       "ge_batch_id": "dab40ca4-1083-11ee-a624-2662aa805206"
#     },
#     "batch_markers": {},
#     "batch_parameters": {},
#     "validation_time": "20230621T223503.418488Z",
#     "expectation_suite_meta": {
#       "great_expectations_version": "0.17.0"
#     }
#   }
# }

# %%
"""
[TO BE IMPLEMENTED]

Take a look at the results from the data validation tests. You will observe that some rows in the
training and test sets have failed the validation for the following test:

Expect the "description" column in Dataframes[ds] not not be null or empty

This is a good catch! We know that these rows in training or test set likely just add noise to the model
since it is not very relevant to ask the model to predict the category of a news article with no text.

In this step, you will filter out the rows from Datasets['train'] and Datasets['test']
and create a new Datasets_filtered object with the filtered datasets
"""

Datasets_filtered = {}
Datasets_filtered['train'] = []
Datasets_filtered['test'] = []

Datasets_filtered = {}
Datasets_filtered['train'] = list(filter(lambda x: x['description'] != "", Datasets['train']))
Datasets_filtered['test'] = list(filter(lambda x: x['description'] != "", Datasets['test']))

print(len(Datasets['train']))
print(len(Datasets['test']))
print(len(Datasets_filtered['train']))
print(len(Datasets_filtered['test']))
# Out:
# 25000
# 50000
# 24736
# 49486

# %% [markdown]
# ## Step 4: Fine-grained Model Evaluation
#
# Model performance evaluation for real-world ML applications can often be complex since different stakeholders (ML engineers, product managers, sales teams) care about the impact on different dimensions. In this exercise, we will evaluate the News category classification from Week 1 in the following ways:
#
#
# * **Aggregate performance metrics**: Using standard metrics to evaluate ML model performance such as accuracy, mean squared error, BLEU scores etc (depending on the ML task) is a necessary first step, but far from sufficient. It serves to filter out models that are clearly suboptimal and reduces risk of launching bad models
#
# * **Slice-level performance metrics**: It is important to track model performance not just in aggregate but for important cohorts/slices of your traffic. For example, it is important to track the performance of your hate speech detection model not just in aggregate but for traffic from each country, language etc to understand the gaps in performance.
#
# * **Qualitative evaluations**: Behavioral tests can be helpful to root-cause individual instances of model failures and yield helpful insights to improve models

# %%
# In order to minimize variations from different model architectures & training procedures,
# we will keep the model architecture and feature sets uniform

X_train, Y_train = [], []
X_test, Y_true = [], []

for row in Datasets_filtered['train']:
    X_train.append(row['embedding'])
    Y_train.append(row['label'])

for row in Datasets_filtered['test']:
    X_test.append(row['embedding'])
    Y_true.append(row['label'])

model = LogisticRegression(
    multi_class='multinomial',
    tol=0.001,
    solver='saga',
)
model.fit(X_train, Y_train)
Y_pred = model.predict(X_test)

# %%
## This should be roughly in the same range as the results you got in Week 1

print("Accuracy on test set: {}".format(sklearn_metrics.accuracy_score(Y_true, Y_pred)))
# Out:
# Accuracy on test set: 0.7894960190761023

# %% [markdown]
# ## Step 4 (Part 1): Confusion Matrix and Slice-based evaluation
#
# As we saw with issues discussed around rare classes and model bias, evaluating the performance metrics at the overall dataset level is often not enough to deploy in production. Here are some commonly used axes along which ML teams commonly slice their datasets:
#
# 1. Labels (i.e. per-class performance)
# 2. Key categorical features or buckets of continuous features. E.g. a recommender system’s performance for each gender, age group.
# 3. Key traffic cohorts as defined by business value/regulatory requirements. E.g. a recommender system’s performance for newly registered users (it is important they have a good product experience else they will stop using the product)
#
# In this exercise, we will dig into per-class performance

# %%
"""
[TO BE IMPLEMENTED]

Plot a confusion matrix for the news category classification model trained above.
You should have a NxN matrix M, where
N = len(LABEL_SET)
M(i, j) = number of instances in the test set where true_label = LABEL_SET[i] and pred_label = LABEL_SET[j]

Hint: check out sklearn.metrics

"""
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay


matrix = confusion_matrix(Y_true, Y_pred, labels=LABEL_SET)
display = ConfusionMatrixDisplay(matrix, display_labels=LABEL_SET)
display.plot(xticks_rotation='vertical')

# %%
"""
[TO BE IMPLEMENTED]

Compute the precision, recall and F1 score per-class for the test set

Hint: check out sklearn.metrics
"""
from sklearn.metrics import classification_report


print(classification_report(Y_true, Y_pred))
# Out:
#                            precision    recall  f1-score   support
#
#                  Business       0.77      0.84      0.80     10675
#             Entertainment       0.77      0.65      0.70     13749
#                    Health       0.75      0.80      0.77      3932
#               Music Feeds       0.97      0.85      0.90       234
#                  Sci/Tech       0.72      0.74      0.73      7881
# Software and Developement       0.71      0.11      0.19       435
#                    Sports       0.87      0.95      0.91     12155
#                     Toons       1.00      1.00      1.00       425
#
#                  accuracy                           0.79     49486
#                 macro avg       0.82      0.74      0.75     49486
#              weighted avg       0.79      0.79      0.78     49486

# %%
import random

def confusion_matrix_errors(X, Y, preds, true_label, pred_label, num_errors=100):
    """
    [TO BE IMPLEMENTED]

    Write a function `confusion_matrix_errors` that accepts the following inputs:
    1. The test dataset
    2. True and predicted labels for each row in the dataset
    3. A pair of labels (T, P)

    And returns the `num_errors` no. of errors from the test dataset where true_label = T and pred_label = P
    """
    errors = []
    for X_i, Y_true_i, Y_pred_i in zip(X, Y, preds):
      if Y_true_i == true_label and Y_pred_i == pred_label:
        errors.append(X_i)
      if len(errors) == num_errors:
        break

    return random.sample(errors, len(errors))



"""
[TO BE IMPLEMENTED]
Use the function implemented above to get some insights about the kind of examples that the model
is confused about for a given pair of classes
Some pairs to try out: ('Entertainment', 'Sports'), ('Health', 'Sports'), ('Business', 'Sci/Tech')
"""
print("Unfiltered Data \nErrors for 'Entertainment' - 'Sports'\n")
for e in confusion_matrix_errors(Datasets['test'], Y_true, Y_pred, 'Entertainment', 'Sports'):
    print(e['description'])

print("\nErrors for 'Entertainment' - 'Sports'\n")
for e in confusion_matrix_errors(Datasets_filtered['test'], Y_true, Y_pred, 'Entertainment', 'Sports', 10):
    print(e['description'])

print("\nErrors for 'Health' - 'Sports'\n")
for e in confusion_matrix_errors(Datasets_filtered['test'], Y_true, Y_pred, 'Health', 'Sports', 10):
    print(e['description'])

print("\nErrors for 'Business' - 'Sci/Tech'\n")
for e in confusion_matrix_errors(Datasets_filtered['test'], Y_true, Y_pred, 'Business', 'Sci/Tech', 10):
    print(e['description'])
# Out:
# Unfiltered Data
# Errors for 'Entertainment' - 'Sports'
#
# Secretary of State Colin L. Powell said yesterday that President Bush will place a high priority in his second term on granting legal status
# Registered voters who have been somehow unregistered. Democrats who suddenly find they #39;ve been re-registered as Republicans. A flier announcing that Election Day has been extended through Wednesday.
# The manner in which the Cavaliers pull their offensive linemen has been a key to their ground attack's success this season.
# PageSix - HOW do you interview   the most famous in  terviewer in the world?
# US search engine Google.com launches a new search service, Google Print, Wednesday (Oct. 6). The service will allow users to search books and help publishers promote their books online for free.
# AP - The Milwaukee Bucks acquired Maurice "Mo" Williams after the Utah Jazz did not match the offer sheet the guard signed on Aug. 6.
# MONTREAL (CP) - A faulty gene may lead some young teenage smokers to be even more susceptible to years of nicotine dependency, a new study suggests.
# HealthDay - SUNDAY, Oct. 24 (HealthDayNews) -- A large Internet study designed to evaluate the best way to help smokers kick the habit is being sponsored by the American Cancer Society.
# The US dollar has recovered ground after days of falls on hopes of healthy US employment news and cheaper oil. The US releases job figures for October at 1330 GMT on Friday, and observers are hoping for about 200,000 new posts.
# Forbes.com - My favorite gadget isn't to be found in the collection featured on the cover. Bruce Upbin, who put these vignettes together, wanted something newfangled, and the Singer model 201 sewing machine I got from a second-hand shop didn't qualify. But it's quite a marvel of mechanical ingenuity and as deserving of a testimonial as those cell phones and iPod docking stations (see p. 72).
# If you still don #39;t believe the Earth is round, check out tonight #39;s lunar eclipse: It was enough to convince the ancient Greeks.
# Babies of teenage mothers and infants who have a low birth weight have a higher risk of committing suicide later in life than other children, Swedish scientists said Friday.
# Verizon Communications, the nation #39;s largest regional phone company, announced plans yesterday to start introducing fiber-optic connections for residential phone and data services in six Eastern states.
# E! Online - It's taken 50 years, 29 movies and, owing to one monster-sized \ tail, who-knows-how-many accidentally knocked over craft-service tables, \ but Godzilla is finally getting his Hollywood coming-out party.
# The Telegraph says Mutu is in rehabilitation and if he comes through that successfully, the Romanian international will be free to join another club next year.
<A HREF="http://www.investor.reuters.com/FullQuote.aspx?ticker=FON.N target=/stocks/quickinfo/fullquote">FON.N</A>, people  familiar with the situation said on Tuesday, lifting a  potential obstacle to Sprint's bid for Nextel Communications  Inc. <A HREF="http://www.investor.reuters.com/FullQuote.aspx?ticker=NXTL.O target=/stocks/quickinfo/fullquote">NXTL.O</A>.
# They spent the summer marveling over their lineup changes and their improvement, the big-name veterans they signed and the strategic concepts they imported from the champion New England Patriots.
# Weyerhaeuser Co. #39;s third-quarter profit rose on higher prices for lumber and a large gain from the sale of timberlands in Georgia, the company said on Friday.
# Oracle's attempted takeover of PeopleSoft can be seen as a harbinger of many more in a mature industry.
# AP - Peter Nowak has played in two MLS Cups  #151; he liked the first a lot better  #151; and gets another crack at the championship this year. The rookie coach will guide D.C. United in Sunday's title game against Kansas City.
# Kenya has met all economic conditions set by the International Monetary Fund (IMF) which could result in the release of a delayed loan to the east African country, a visiting IMF mission announced here Friday.
# Three Hollywood studios are to use next-generation DVD technology backed by Toshiba, snubbing a rival product promoted by Sony.
# Manchester United boss Sir Alex Ferguson has admitted that his expensively restructured squad deserves to be written off as serious Premiership title challengers.
# HIV carriers in China may have a chance to become civil servants under a new health standard for recruitment, reported China Daily on Saturday.
# Plus: eBay outlines policy on racist language. News.com Extra
# Els said the American-based Tour wants him to play in more events, but he considers himself a global golfer.  quot;I think they need to understand that I think the golfing world has changed
# Shares of Manchester United fell Monday as investors questioned the likelihood of a \$1.5 billion bid from Malcolm Glazer after the US tycoon #39;s bankers resigned.
# Looks like the Greatest Show on Turf is in high gear -- on offense and defense. Torry Holt caught two long touchdown passes and Adam Archuletta returned a fumble 93 yards Monday night, keying the Rams #39; 28-21 victory over Tampa Bay.
# Iran is unlikely to accept European incentives aimed at getting it to suspend uranium enrichment, diplomats said Thursday, raising the prospect of a showdown next
# LONDON (Reuters) - Health experts urged Ireland to  introduce a national screening program for cervical cancer  after a report published on Tuesday revealed deaths from the  disease are higher than in Britain and Northern Ireland.
# The O #39;Reilly family, owners of the Independent and Independent on Sunday, rarely give press interviews. A solution to the sales decline at their UK newspapers has been equally elusive over the past decade, but
# Attempting to fine-tune its software for use in business-critical applications, Blue Titan Software on Monday is unveiling Network Director RM (Reliable Messaging), a tool for policy distribution and messaging in SOAs (service-oriented architectures).
# Sony Corp. and several financial partners have agreed in principle to acquire movie studio Metro-Goldwyn-Mayer for about \$2.94 billion in cash, sources familiar with the talks said Monday.
# Reuters - At least 62.5 million Americans\tuned in to President Bush's debate with challenger Sen. John\Kerry on Thursday, far surpassing the number who watched either\political convention this summer or Bush's debates four years\ago with Al Gore.
# Reuters - The NASD on Monday said it fined\Citigroup Global Markets Inc.  #36;250,000 for distributing\inappropriate hedge fund sales literature, in the regulator's\largest fine involving hedge fund sales by broker-dealers.
# The Motley Fool - Mutual fund data provider Morningstar appears to have made a relatively minor, correctable error regarding data from hedge fund Rock Canyon Top Flight (FUND: TOPFX). However, the company still received a Wells Notice that the Securities and Exchange Commission is investigating its publication of the incorrect total return data. Add to this the backdrop of a possible Morningstar IPO, and you've got the makings of a good drama.
# England skipper David Beckham has denied reports he will quit playing for his country after the 2006 World Cup. The 29-year-old Real Madrid star says he hopes to reach 100 international caps and has no plans to retire from international football yet.
# The US Open will either get its dream all-American final, a nightmare all-Russian final, or something in between today when No. 5 Lindsay Davenport faces No.
#
# Errors for 'Health' - 'Sports'
#
# Kristin Ott laced up her in-line skates at the parking lot by Green Lake #39;s community center, ready to enjoy one of Seattle #39;s last sunny days for a while -- and perhaps one of the last days of being able to park free at the park.
# Sudbury #39;s Betty Zheng, a senior assistant captain on the Massachusetts Institute of Technology women #39;s ice hockey team, will always remember MIT #39;s Dec. 3 game against Chatham (Pa.
# NEW HAVEN, Conn.Older runners are improving their performance more quickly than younger runners, a Yale study has found, raising new awareness of the ability of older athletes and the benefits of exercise for people 50 and older.
# NEW YORK -- Baseball commissioner Bud Selig had surgery Monday to remove a cancerous lesion from his forehead. The lesion was detected last month during Selig #39;s annual physical, and a biopsy confirmed that it contained melanoma, a form of skin cancer.
# There is Heinz Field, home of the Steelers football team, the Heinz chapel, with its 23 stained glass windows, the Heinz hall for music lovers, the Heinz Gallery for visual art, and coming soon, in a converted red-brick factory, the Heinz riverside luxury
# Young women who injure their knees playing soccer appear to have a very high chance of developing a potentially disabling arthritis years later, a study suggests.
# In a sense, older runners are flying by their younger counterparts in New York City marathons, study findings show. They may not cross the finish line first
# NEW YORK (Reuters Health) - Body shaving and "turf burns"  seem to be two of the factors that raise football players' risk  of contracting an increasingly common antibiotic-resistant skin  infection, U.S. health officials report.
# Kermit Washington had gone back to American University on many occasions over the years -- the night they retired his basketball jersey, the times he needed a gym to run his clinics for aspiring players.
# The Sweetwater Union High School District has chosen 55 acres south of Olympic Parkway in Chula Vista as the site for South County #39;s next high school, scheduled to open in July 2006.
#
# Errors for 'Business' - 'Sci/Tech'
#
# Three Hollywood studios choose to use next-generation DVD technology backed by Toshiba, snubbing a rival product promoted by Sony.
# If you can't answer that question, please read on.
# ZDNet #39;s survey of IT professionals in August kept Wired  amp; Wireless on top for the 18th month in a row. AT amp;T will cut about 7,000 jobs and reduce the value of its assets by \$11.
# Cingular Wireless, the largest US cellphone service provider, has announced plans to upgrade its high-speed data network, allowing faster downloads than are now available on many home broadband connections.
# D.C. has hired a group to develop new design standards for downtown food carts and souvenir stands.
# Bruce Goodman is shopping for a new plasma television. He #39;s been doing that for a while -- about six months.  quot;It #39;s much more work than it ought to be, quot; he said of his research.
# I.B.M., whose first PC moved personal computing out of the hobby shop and into the consumer mainstream, has put the business up for sale.
# Nextel Communications Inc. and Verizon Wireless are settling all legal disputes between them, removing a key challenge to a federal decision to clear up interference between cell phones and emergency response
# The vendors will collaborate on their approaches to PC quarantines, but Microsoft #39;s Network Access Protection gets delayed by more than a year.
# Hoping to both bolster resources available to its network of business partners as well as expand its number of partners, IBM on Tuesday introduced services and support programs that boost financial support for co-marketing campaigns and grant deeper access to IBMs sales network to close deals faster.

# %% [markdown]
# ## Step 4 (Part 2): Estimating confidence intervals with Bootstrap sampling
#
# When computing model performance metrics, the margin of error can vary a lot depending on the size of the test dataset. We are trying to estimate the model’s performance on any unseen data by empirically computing the model performance on the held-out test set, and trying to quantify the confidence intervals in this estimation: If we were to measure the model’s performance on another independently collected test dataset from the same underlying distribution, our model’s performance on this dataset is unlikely to be the same, but how different might they plausibly be?
#
# In this exercise, we will implement Bootstrap sampling to estimate the 95% confidence interval for
# overall accuracy and F1-score of the model:
#
# 1. Generate N ‘bootstrap sample’ datasets, each the same size as the original test set. Each bootstrap sample dataset is obtained by sampling instances uniformly at random from the original test set (with replacement).
# 2. On each of the bootstrap sample datasets, calculate the accuracy metric.
# 3. From Step (2), you will end up with N different accuracy values. Sort them.
# 4. The 95% confidence interval is given by the 2.5th to the 97.5th percentile among the N sorted accuracy values.

# %%
def bootstrap_accuracy_distribution(Y_true, Y_pred, N = 1000):
    """
    [TO BE IMPLEMENTED]

    Implement this function that takes two lists: Y_true, Y_pred
    and the number of bootstrap trials (N).

    It should return a list (ret) of length = N, where ret[i] = accuracy metric from i-th bootstrap sampling run
    """
    true_samples = int(len(Y_true) * 0.2) 
    # print(true_samples)
    bootstrap_vals = [0]*N

    matches = []
    for Y_true_i, Y_pred_i in list(zip(Y_true, Y_pred)):
        matches.append(int(Y_true_i == Y_pred_i))

    for i in range(N):
        bootstrap_vals[i] = sum(random.sample(matches, true_samples)) / true_samples
    
    return bootstrap_vals

# %%
import matplotlib.pyplot as plt
NUM_BOOTSTRAP = 1000

bs_vals = bootstrap_accuracy_distribution(Y_true, Y_pred, NUM_BOOTSTRAP)
bs_vals = sorted(bs_vals)

print("95 percent confidence interval: [{0}, {1}]".format(
    bs_vals[25],    # 2.5th percentile
    bs_vals[975]    # 97.5th percentile
))

_ = plt.hist(bs_vals, bins='auto')
plt.show()
# Out:
# 95 percent confidence interval: [0.7825603718298474, 0.7969081539860564]

# %% [markdown]
# ## Step 4 (Part 3): Minimum Functionality behavioral Tests
#
# Unit tests and integration tests play an important role in testing software for bugs, inefficiencies and potential vulnerabilities. Can we employ a similar approach to testing ML models? This exercise introduces the concept of “behavioral testing”  for machine learning models.
#
# Minimum Functionality Tests are a class of behavioral tests, and equivalents of “unit tests in software engineering” - a collection of simple examples (and labels) to check a behavior. A recommended practice is to write minimum functionality tests for highly visible/high cost potential failure modes, and for failure modes that you uncover during error analysis to guard against such failures in the future.
#
# For this exercise, we will use a popular open source library called [Checklist](https://github.com/marcotcr/checklist) to configure and run behavioral tests for our model. The goal and scope of the exercise here is to get you acquainted with the library and practice of testing for minimum functionality.
#
# Useful references:
# 1. Getting started with Checklist: https://github.com/marcotcr/checklist
# 2. Creating & Running tests with Checklist: https://github.com/marcotcr/checklist/blob/9baab717e44e216697f7ef0730ee269db9ef7d5b/notebooks/tutorials/3.%20Test%20types,%20expectation%20functions,%20running%20tests.ipynb

# %%
pip install checklist
# Out:
# Requirement already satisfied: checklist in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (0.0.11)
# Requirement already satisfied: numpy>=1.18 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from checklist) (1.24.2)
# Requirement already satisfied: spacy>=2.2 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from checklist) (3.5.3)
# Requirement already satisfied: munch>=2.5 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from checklist) (3.0.0)
# Requirement already satisfied: dill>=0.3.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from checklist) (0.3.6)
# Requirement already satisfied: jupyter>=1.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from checklist) (1.0.0)
# Requirement already satisfied: ipywidgets>=7.5 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from checklist) (8.0.6)
# Requirement already satisfied: transformers>=2.8 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from checklist) (4.29.2)
# Requirement already satisfied: patternfork-nosql in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from checklist) (3.6)
# Requirement already satisfied: iso-639 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from checklist) (0.4.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipywidgets>=7.5->checklist) (6.23.0)
# Requirement already satisfied: ipython>=6.1.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipywidgets>=7.5->checklist) (8.13.2)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipywidgets>=7.5->checklist) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipywidgets>=7.5->checklist) (4.0.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipywidgets>=7.5->checklist) (3.0.7)
# Requirement already satisfied: notebook in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter>=1.0->checklist) (6.5.4)
# Requirement already satisfied: qtconsole in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter>=1.0->checklist) (5.4.3)
# Requirement already satisfied: jupyter-console in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter>=1.0->checklist) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter>=1.0->checklist) (7.5.0)
# Requirement already satisfied: six in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from munch>=2.5->checklist) (1.16.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from spacy>=2.2->checklist) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from spacy>=2.2->checklist) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from spacy>=2.2->checklist) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from spacy>=2.2->checklist) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from spacy>=2.2->checklist) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from spacy>=2.2->checklist) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from spacy>=2.2->checklist) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from spacy>=2.2->checklist) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from spacy>=2.2->checklist) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from spacy>=2.2->checklist) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from spacy>=2.2->checklist) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from spacy>=2.2->checklist) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from spacy>=2.2->checklist) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from spacy>=2.2->checklist) (2.30.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from spacy>=2.2->checklist) (1.10.8)
# Requirement already satisfied: jinja2 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from spacy>=2.2->checklist) (3.1.2)
# Requirement already satisfied: setuptools in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from spacy>=2.2->checklist) (57.4.0)
# Requirement already satisfied: packaging>=20.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from spacy>=2.2->checklist) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from spacy>=2.2->checklist) (3.3.0)
# Requirement already satisfied: filelock in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from transformers>=2.8->checklist) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from transformers>=2.8->checklist) (0.15.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from transformers>=2.8->checklist) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from transformers>=2.8->checklist) (2023.6.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from transformers>=2.8->checklist) (0.13.3)
# Requirement already satisfied: future in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from patternfork-nosql->checklist) (0.18.3)
# Requirement already satisfied: backports.csv in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from patternfork-nosql->checklist) (1.0.7)
# Requirement already satisfied: beautifulsoup4 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from patternfork-nosql->checklist) (4.12.2)
# Requirement already satisfied: lxml in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from patternfork-nosql->checklist) (4.9.2)
# Requirement already satisfied: feedparser in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from patternfork-nosql->checklist) (6.0.10)
# Requirement already satisfied: pdfminer.six in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from patternfork-nosql->checklist) (20221105)
# Requirement already satisfied: scipy in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from patternfork-nosql->checklist) (1.10.1)
# Requirement already satisfied: nltk in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from patternfork-nosql->checklist) (3.8.1)
# Requirement already satisfied: python-docx in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from patternfork-nosql->checklist) (0.8.11)
# Requirement already satisfied: cherrypy in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from patternfork-nosql->checklist) (18.8.0)
# Requirement already satisfied: fsspec in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers>=2.8->checklist) (2023.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers>=2.8->checklist) (4.6.3)
# Requirement already satisfied: appnope in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->checklist) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->checklist) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->checklist) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->checklist) (8.2.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->checklist) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->checklist) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->checklist) (1.5.6)
# Requirement already satisfied: psutil in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->checklist) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->checklist) (25.0.2)
# Requirement already satisfied: tornado>=6.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->checklist) (6.3.1)
# Requirement already satisfied: backcall in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5->checklist) (0.2.0)
# Requirement already satisfied: decorator in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5->checklist) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5->checklist) (0.18.2)
# Requirement already satisfied: pickleshare in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5->checklist) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5->checklist) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5->checklist) (2.15.1)
# Requirement already satisfied: stack-data in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5->checklist) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.5->checklist) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2->checklist) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2->checklist) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2->checklist) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2->checklist) (2023.5.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy>=2.2->checklist) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy>=2.2->checklist) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy>=2.2->checklist) (8.1.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from beautifulsoup4->patternfork-nosql->checklist) (2.4.1)
# Requirement already satisfied: cheroot>=8.2.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from cherrypy->patternfork-nosql->checklist) (10.0.0)
# Requirement already satisfied: portend>=2.1.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from cherrypy->patternfork-nosql->checklist) (3.1.0)
# Requirement already satisfied: more-itertools in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from cherrypy->patternfork-nosql->checklist) (9.1.0)
# Requirement already satisfied: zc.lockfile in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from cherrypy->patternfork-nosql->checklist) (3.0.post1)
# Requirement already satisfied: jaraco.collections in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from cherrypy->patternfork-nosql->checklist) (4.2.0)
# Requirement already satisfied: sgmllib3k in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from feedparser->patternfork-nosql->checklist) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jinja2->spacy>=2.2->checklist) (2.1.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0->checklist) (6.0.0)
# Requirement already satisfied: defusedxml in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0->checklist) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0->checklist) (0.2.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0->checklist) (2.0.5)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0->checklist) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0->checklist) (5.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0->checklist) (1.5.0)
# Requirement already satisfied: tinycss2 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbconvert->jupyter>=1.0->checklist) (1.2.1)
# Requirement already satisfied: joblib in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nltk->patternfork-nosql->checklist) (1.2.0)
# Requirement already satisfied: argon2-cffi in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from notebook->jupyter>=1.0->checklist) (21.3.0)
# Requirement already satisfied: ipython-genutils in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from notebook->jupyter>=1.0->checklist) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from notebook->jupyter>=1.0->checklist) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from notebook->jupyter>=1.0->checklist) (0.17.1)
# Requirement already satisfied: prometheus-client in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from notebook->jupyter>=1.0->checklist) (0.17.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from notebook->jupyter>=1.0->checklist) (1.0.0)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from pdfminer.six->patternfork-nosql->checklist) (41.0.1)
# Requirement already satisfied: qtpy>=2.0.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from qtconsole->jupyter>=1.0->checklist) (2.3.1)
# Requirement already satisfied: webencodings in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter>=1.0->checklist) (0.5.1)
# Requirement already satisfied: jaraco.functools in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from cheroot>=8.2.1->cherrypy->patternfork-nosql->checklist) (3.7.0)
# Requirement already satisfied: cffi>=1.12 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from cryptography>=36.0.0->pdfminer.six->patternfork-nosql->checklist) (1.15.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.5->checklist) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.5->checklist) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.5->checklist) (3.5.0)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (2.6.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (0.2.3)
# Requirement already satisfied: fastjsonschema in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter>=1.0->checklist) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter>=1.0->checklist) (4.17.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.5->checklist) (0.7.0)
# Requirement already satisfied: tempora>=1.8 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from portend>=2.1.1->cherrypy->patternfork-nosql->checklist) (5.3.0)
# Requirement already satisfied: wcwidth in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=7.5->checklist) (0.2.6)
# Requirement already satisfied: argon2-cffi-bindings in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from argon2-cffi->notebook->jupyter>=1.0->checklist) (21.2.0)
# Requirement already satisfied: jaraco.text in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jaraco.collections->cherrypy->patternfork-nosql->checklist) (3.11.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5->checklist) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5->checklist) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5->checklist) (0.2.2)
# Requirement already satisfied: pycparser in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->patternfork-nosql->checklist) (2.21)
# Requirement already satisfied: attrs>=17.4.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter>=1.0->checklist) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter>=1.0->checklist) (0.19.3)
# Requirement already satisfied: anyio>=3.1.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (3.7.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (0.4.4)
# Requirement already satisfied: overrides in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (7.3.1)
# Requirement already satisfied: websocket-client in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (1.5.3)
# Requirement already satisfied: pytz in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->patternfork-nosql->checklist) (2023.3)
# Requirement already satisfied: jaraco.context>=4.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jaraco.text->jaraco.collections->cherrypy->patternfork-nosql->checklist) (4.3.0)
# Requirement already satisfied: autocommand in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jaraco.text->jaraco.collections->cherrypy->patternfork-nosql->checklist) (2.2.2)
# Requirement already satisfied: inflect in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jaraco.text->jaraco.collections->cherrypy->patternfork-nosql->checklist) (6.0.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (1.3.0)
# Requirement already satisfied: exceptiongroup in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (1.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0->checklist) (0.1.1)
# Requirement already satisfied: fqdn in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter>=1.0->checklist) (1.5.1)
# Requirement already satisfied: isoduration in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter>=1.0->checklist) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter>=1.0->checklist) (2.4)
# Requirement already satisfied: uri-template in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter>=1.0->checklist) (1.2.0)
# Requirement already satisfied: webcolors>=1.11 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter>=1.0->checklist) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /Users/sjabbireddy/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from isoduration->jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter>=1.0->checklist) (1.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import checklist
from checklist.editor import Editor
from checklist.test_types import MFT
from checklist.pred_wrapper import PredictorWrapper

# Run some warmup code to get you familiar with templates in checlist
editor = Editor()
ret = editor.template('{first_name} is {a:profession} from {country}.',
                      profession=['lawyer', 'doctor', 'accountant'])
np.random.choice(ret.data, 3)
# Out:
# array(['Louis is a lawyer from Lebanon.',
#        'Matt is an accountant from Ukraine.',
#        'Jennifer is a doctor from South Sudan.'], dtype='<U67')

# %%
"""
[TO BE IMPLEMENTED]

Part 1: Data Generation for behavioral tests

1. News Source variation:
{source}: Astronomers expect the Perseid meteor shower to be one of the best versions of the shooting star events in several years
source = ['New York Times', 'Reuters', 'AP', 'Wall Street Journal', 'Quanta', 'BBC', 'BBC UK', 'Yahoo News']
labels = "Sci/Tech"

2. Company Name variation:
{company} revealed Thursday that its old recipe of adding stores is longer is a source of new profits for the company.
company = ['McDonalds', 'Starbucks', 'Chipotle', 'Krispy Creme', 'Unknown Company']
labels = "Sci/Tech"

3.
{disease} will come under the {mask} during the charity gala event being held on Monday at 7pm
disease = ['Breast cancer', 'Heart disease', 'Diabetes']
labels = "Health"
"""

editor = Editor()
# [TO BE IMPLEMENTED]
# ret = editor.template(...)
ret = editor.template('{source} Astronomers expect the Perseid meteor shower to be one of the best versions of the shooting star events in several years',
                source = ['New York Times', 'Reuters', 'AP', 'Wall Street Journal', 'Quanta', 'BBC', 'BBC UK', 'Yahoo News'],
                labels = "Sci/Tech")

# ret += editor.template(...)
ret += editor.template('{company} revealed Thursday that its old recipe of adding stores is longer is a source of new profits for the company.',
                      company = ['McDonalds', 'Starbucks', 'Chipotle', 'Krispy Creme', 'Unknown Company'],
                      labels = "Sci/Tech")

# ret += editor.template(...)
ret += editor.template('{disease} will come under the {mask} during the charity gala event being held on Monday at 7pm',
                      disease = ['Breast cancer', 'Heart disease', 'Diabetes'],
                      labels = "Health")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json: 0.00B [00:00, ?B/s]
# Downloading (…)olve/main/merges.txt: 0.00B [00:00, ?B/s]
# Downloading (…)/main/tokenizer.json: 0.00B [00:00, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/501M [00:00<?, ?B/s]

# %%
"""
Part 2: Test Configuration
"""

test = MFT(**ret, name='AG News MFT tests')

# %%
"""
Part 3: Test Run & Results summary
"""

def encode_and_predict(inputs):
    encoder = SentenceTransformer(
        'sentence-transformers/{model}'.format(model=EMBEDDING_MODEL)
    )
    encodings = [encoder.encode(x, normalize_embeddings=True) for x in inputs]
    return model.predict(encodings)

# wrapped_pp returns a tuple with (predictions, softmax confidences)
wrapped_pp = PredictorWrapper.wrap_predict(encode_and_predict)
test.run(wrapped_pp, overwrite=True)
test.summary()
# Out:
# Predicting 313 examples
# Test cases:      313
# Fails (rate):    11 (3.5%)
#
# Example fails:
# Business Starbucks revealed Thursday that its old recipe of adding stores is longer is a source of new profits for the company.
# ----
# Entertainment Breast cancer will come under the stage during the charity gala event being held on Monday at 7pm
# ----
# Business Krispy Creme revealed Thursday that its old recipe of adding stores is longer is a source of new profits for the company.
# ----

# %% [markdown]
# ## Step 5: [Optional] Advanced data quality and behavioral tests
#
# In the previous steps, you have familiarized yourself with libraries for writing data quality tests (great expectations) and behavioral tests (checkist). Take it out for a spin! A few possible extensions you can try:
#
# 1. **Model invariance behavioral tests** -- in step 4, we wrote some minimum functionality tests. Can you design some useful invariance behavioral tests?
#
# 2. **Embedding drift based data quality checks across Training/Test datasets** -- in step 3, we wrote some data quality tests. If we wanted to check for drift in embedding space between training and test data, how might we construct a data quality test for this? Hint: The distribution of euclidean distance between pairs of embeddings within the training, and between the training and test dataset should be “almost the same”

# %% [markdown]
# ## Step 6 [Optional] Examing the impact of label noise on model performance
#
# we have studied the impact of intelligently augmenting data to improve model performance. An equally important consideration is the quality of labels (both in the training and validation datasets) - label noise can lead to suboptimal performance in two ways:
# (i) noise in the validation dataset can lead us to compute model performance on incorrect ground truth labels
# (ii) noise in the training dataset can lead the model to learning incorrect correlations between input features and the ground truth label.
#
# [Cleanlab](https://docs.cleanlab.ai/stable/index.html) is a popular open source library to detect and fix label errors in datasets, by using a technique called confident learning. If you are interested to learn more, take a look at:
# * published paper: https://jair.org/index.php/jair/article/view/12125
# * blog: https://l7.curtisnorthcutt.com/confident-learning
#
# Use Cleanlab to identify labeling errors in the AG News dataset, and report any improvement in model performance. Note that
#
# Some starter tutorials/code snippets that might be helpful:
# * [Text classification tutorial](https://docs.cleanlab.ai/stable/tutorials/text.html)
# * [API Documentation](https://docs.cleanlab.ai/stable/index.html)
# * [Common example notebooks](https://github.com/cleanlab/examples)

# %%
'''
[TO BE IMPLEMENTED]

Your label noise experimentations go here

For instance, one exploration might look like the following:

import cleanlab

## Train cleanlab model
cl = cleanlab.classification.CleanLearning(
  LogisticRegression(
    multi_class='multinomial',
    tol=0.001,
    solver='saga',
))
cl.fit(<train>, <train labels>)

## Use the trained model to identify potential issues
label_issues_training = cl.find_label_issues(<train labels>, cl.predict(<train>))
label_issues_test = cl.find_label_issues(<test labels>, cl.predict(<test>))

## Use the identified issues to update the ground truth labels
## Train the new model and record performance improvements

'''
